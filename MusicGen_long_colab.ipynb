# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/MusicGen-colab/blob/main/MusicGen_long_colab.ipynb)

# %%
# %cd /content
# !git clone -b bg https://github.com/camenduru/audiocraft
# %cd /content/audiocraft
# !pip install -r requirements.txt
# !python app.py --share
